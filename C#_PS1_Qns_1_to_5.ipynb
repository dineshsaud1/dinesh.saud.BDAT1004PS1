# %% [markdown]
# # C # Assingment

# %% [markdown]
# ## Question 1 C#
# * 5 is an Integer.
# * 5.0 is a Double.
# * 5  > 1 is a Boolean expression, checking True or False.
# * '5' represents a Character.
# * 5 * 2 (10 and is an Integer.
# * '5' * 2 results in '55' and is a String.
# * '5' + '2' yields '52' and is also a String.
# * 5 / 2 equals 2 and is an Integer.
# * 5 % 2 equals 1 and is an Integer.
# * { 5, 2, 1} is an Array containing the values 5, 2, and 1.
# * 5 == 3 is a Boolean expression, evaluating to either True or False.
# * Pi (approximately 3.14) is a Double, representing the mathematical constant π.

# %% [markdown]
# ## Question 2 C#
# Write (and evaluate) C# expressions that answer these questions:
# <br>
# a. How many letters are there in 'Supercalifragilisticexpialidocious'?
# <br>
# b. Does 'Supercalifragilisticexpialidocious' contain 'ice' as a substring?
# <br>
# c. Which of the following words is the longest:
# Supercalifragilisticexpialidocious, Honorificabilitudinitatibus, or Bababadalgharaghtakamminarronnkonn?
# <br>
# d. Which composer comes first in the dictionary: 'Berlioz', 'Borodin', 'Brian',
# 'Bartok', 'Bellini', 'Buxtehude', 'Bernstein'.
# <br>
# Which one comes last?

# %%
internal class Program
{
    private static void Main(string[] args)
    {
        # 2a) How many letters are there in 'Supercalifragilisticexpialidocious'?

        string inputStr = "Supercalifragilisticexpialidocious";
        Console.WriteLine($"Number of letters in {inputStr}: {inputStr.Length}");

        # Task 2b) Does 'Supercalifragilisticexpialidocious' contain 'ice' as a substring?


        string SearchWord = "ice";

        int SearchWordIndex = FindSubstring(inputStr, SearchWord);

        if (SearchWordIndex != -1)
            Console.WriteLine($"Yes! {SearchWord} is found at index {SearchWordIndex}");
        else
            Console.WriteLine($"'{SearchWord}' not found");

        static int FindSubstring(string inputStr, string SearchWord)
        {
            int inputStrLength = inputStr.Length;
            int patternLength = SearchWord.Length;

            for (int i = 0; i <= inputStrLength - patternLength; i++)
            {
                int j;
                for (j = 0; j < patternLength; j++)
                {
                    if (inputStr[i + j] != SearchWord[j])
                        break;
                }

                if (j == patternLength)
                    return i; # Match found
            }

            return -1; # No match found
        }

#Task 2c) Which of the following words is the longest:Supercalifragilisticexpialidocious, Honorificabilitudinitatibus, orBababadalgharaghtakamminarronnko

        string _1stWord = "Supercalifragilisticexpialidocious";
        string _2ndWord = " Honorificabilitudinitatibus";
        string _3rdWord = "Bababadalgharaghtakamminarronnkonn";

        int word1Length = _1stWord.Length;
        int word2Length = _2ndWord.Length;
        int word3Length = _3rdWord.Length;

        if (word1Length > word2Length && word1Length > word3Length)
            Console.WriteLine($"The longest string is '{_1stWord}'");
        else if (word2Length > word1Length && word2Length > word3Length)
            Console.WriteLine($"The longest string is '{_2ndWord}'");
        else
            Console.WriteLine($"The longest string is '{_3rdWord}'");

  #Task 2d) Which composer comes first in the dictionary: 'Berlioz', 'Borodin', 'Brian','Bartok', 'Bellini', 'Buxtehude', 'Bernstein'. Which one comes last? 

        string[] composerArray = {"Berlioz", "Borodin", "Brian",
                                  "Bartok", "Bellini", "Buxtehude", "Bernstein"};
        Array.Sort(composerArray);
        Console.WriteLine($"The word that comes first in the dictionary: '{composerArray[0]}'");
        Console.WriteLine($"The word that comes last in the dictionary: '{composerArray[composerArray.Length - 1]}'");
    }
}

# %% [markdown]
# ## Queston 3 C#
# Implement function triangleArea(a,b,c) that takes as input the lengths of the 3 sides of a triangle and returns the area of the triangle. By Heron's formula, the area of a triangle with side lengths a, b, and c is s(s - a)(s -b)(s -c), where s = (a+b+c)/2.

# %%
internal class Program
{
    private static void Main(string[] args)
    {
        Console.Write("Enter the length of the first side of the triangle (a): ");
        double A = double.Parse(Console.ReadLine());

        Console.Write("Enter the length of the second side of the triangle (b): ");
        double B = double.Parse(Console.ReadLine());

        Console.Write("Enter the length of the third side of the triangle (c): ");
        double C = double.Parse(Console.ReadLine());

        double CalculateTriangleArea(double a, double b, double c)
        {
            double s = (a + b + c) / 2;
            double area = Math.Sqrt(s * (s - a) * (s - b) * (s - c));
            return area;
        }

        double area = CalculateTriangleArea(A, B, C);

        Console.WriteLine($"Area of the triangle with sides a={A}, b={B}, and c={C} is is {area}");



    }
}

# %% [markdown]
# ## Question 4 C#
# Write a program in C# Sharp to separate odd and even integers in separate arrays.
# Go to the editor
# Test Data
# :Input the number of elements to be stored in the array :5
# Input 5 elements in the array :
# element - 0 : 25
# element - 1 : 47
# element - 2 : 42
# element - 3 : 56
# element - 4 : 32
# Expected Output:The Even elements are:42 56 32
# The Odd elements a:
# 25 47

# %%
using System;

class Program
{
    static void Main(string[] args)
    {
        Console.Write("Enter the number of elements to be stored in the array: ");
        int total_num_elements = int.Parse(Console.ReadLine());
        int[] num_array = new int[total_num_elements];
        int[] even_num_array = new int[total_num_elements];
        int[] odd_num_array = new int[total_num_elements];


        Console.WriteLine($"Input {total_num_elements} elements into the array:");

        for (int i = 0; i < total_num_elements; i++)
        {
            Console.Write($"Element {i + 1}: ");
            num_array[i] = int.Parse(Console.ReadLine());
        }

        int even_count = 0;
        int odd_count = 0;

        foreach (int num in num_array)
        {
            if (num % 2 == 0)
            {
                even_num_array[even_count] = num;
                even_count++;
            }
            else
            {
                odd_num_array[odd_count] = num;
                odd_count++;
            }
        }

        Console.WriteLine("Even elements:");

        for (int i = 0; i < even_count; i++)
        {
            Console.Write(even_num_array[i] + " ");
        }

        Console.WriteLine("\nOdd elements:");

        for (int i = 0; i < odd_count; i++)
        {
            Console.Write(odd_num_array[i] + " ");
        }
    }
}

# %% [markdown]
# # Question 5
# <br>
#  a. Write a function inside(x,y,x1,y1,x2,y2) that returns True or Falsedepending on whether the point (x,y) lies in the rectangle with lower leftcorner (x1,y1) and upper right corner (x2,y2).
#
# <br>
# <br>
#       >>> inside(1,1,0,0,2,3)True>>> inside(-1,-1,0,0,2,3)False
#
# <br>
# b. Use function inside() from part a. to write an expression that tests whetherthe point (1,1) lies in both of the following rectangles: one with lower leftcorner (0.3, 0.5) and upper right corner (1.1, 0.7) and the other with lowerleft corner (0.5, 0.2) and upper right corner (1.1

# %%
using System;

class Program
{
    static void Main(string[] args)
    {
        bool IsPointInsideRectangle(double x, double y, double x1, double y1, double x2, double y2)
        {
            double lowerLeftCornerX = x - x1;
            double lowerLeftCornerY = y - y1;
            double upperRightCornerX = x2 - x;
            double upperRightCornerY = y2 - y;
            bool check = false;

            if ((lowerLeftCornerX > 0 && lowerLeftCornerY > 0) && (upperRightCornerX > 0 && upperRightCornerY > 0))
            {
                check = true;
            }
            else
            {
                check = false;
            }

            return check;
        }

        bool isInsideRectangle1 = IsPointInsideRectangle(1, 1, 0.3, 0.5, 1.1, 0.7);
        bool isInsideRectangle2 = IsPointInsideRectangle(1, 1, 0.5, 0.2, 1.1, 2);

        if (isInsideRectangle1 && isInsideRectangle2)
        {
            Console.WriteLine("(1,1) lies in both of the given rectangles.");
        }
        else
        {
            Console.WriteLine("(1,1) doesn't lie in both of the given rectangles.");
        }
    }
}
